# %% [markdown]
# # Ground Motion Displacement RMS vs Time
#
# *an example simple tutorial for getting seismic data, computing the power spectral densities, extracting the RMS and plotting*
#
# Required:
#
# - python
# - obspy (and its dependencies)
# - pandas
# - jupyter
# - notebook
#
# this should be easy to set up in a conda env: ``conda create -n covid python=3.7 obspy pandas jupyter notebook``
#
# Author: Thomas Lecocq @seismotom, Fred Massin @fmassin

# %% [markdown]
# ## Step 1: imports

# %%
import datetime
import os
import glob

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import pandas as pd

from obspy import UTCDateTime, read
from obspy.clients.fdsn import Client
from obspy.signal import PPSD

# %% [markdown]
# ## Step 2: Define Start/End dates and Seismic Channel
#
# You'll have to make sure the seed_id you request is indeed available from the ``data_provider``

# %%
start = UTCDateTime("2020-02-13")
end = UTCDateTime() # means "now"

network = "CH"
station = "SBERN,SZUZ,SGEV"#,SLOP,SUSI,SEPFL,SBAM2," # Urban stations
#station = "SEPFL,SMOE,SBUL,SIEB,SIZS,SLENK,SMEIS,SARD,SBJN,SCHAT,SEFS," # School stations, change on 1rst ban?
#station = "SCRM,SALTS,SBAS,SBRS,SCHS,SDES,SSTS,SWIS," # Hospital stations, less of a decrease than others ?
#station = "NALPS,JAUN,BRANT,FUORN" # Good free field stations, nothing?
#station = "BERNI,SIMPL," # Alpine mountain passes, people traveling on the weekend,?
location = ""
channel = "HG*"

data_provider = "ETH"
logo = plt.imread('https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Logo_SED_2014.png/220px-Logo_SED_2014.png')
bans = {"2020-03-13":'Groups >100 banned', "2020-03-20":'Groups >5 banned'}

# %% [markdown]
# ## Step 3: Download the seismic waveform data
#
# This step is coded so that only the last day is redownloaded iif the daily files are present on the disk.
#
# The request gets the target day +- 30 minutes to avoid having gaps at the end of each day (need 1 window covering midnight).

# %%
datelist = pd.date_range(start.datetime, end.datetime, freq="D")
c = Client(data_provider)

for day in datelist:
    fn = day.strftime("%Y-%m-%d.mseed")
    print(fn)
    if day != datelist[-1] and os.path.isfile(fn):
        continue
    else:
        st = c.get_waveforms(network, station, location, channel,
                             UTCDateTime(day)-1801, UTCDateTime(day)+86400+1801, attach_response=True)
        print(st)
        st.write(fn)
resp = c.get_stations(UTCDateTime(day), network=network, station=station, location=location,
                      channel=channel, level="response")
print(resp)
# Out:
# 2020-02-13.mseed
# 33 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-12T23:29:57.932000Z - 2020-02-14T00:05:23.948000Z | 250.0 Hz, 22131505 samples
# ...
# (31 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-12T23:29:57.504000Z - 2020-02-14T00:30:01.920000Z | 250.0 Hz, 22501105 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/io/mseed/core.py:807: UserWarning: File will be written with more than one different encodings.
# This might have a negative influence on the compatibility with other programs.
#   warnings.warn(msg % 'encodings')
# 2020-02-14.mseed
# 320 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-13T23:29:58.984000Z - 2020-02-14T00:05:23.948000Z | 250.0 Hz, 531242 samples
# ...
# (318 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-14T09:29:54.692000Z - 2020-02-15T00:30:02.432000Z | 250.0 Hz, 13501936 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-15.mseed
# 195 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-14T23:29:57.864000Z - 2020-02-15T01:05:53.220000Z | 250.0 Hz, 1438840 samples
# ...
# (193 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-14T23:29:58.108000Z - 2020-02-16T00:30:01.312000Z | 250.0 Hz, 22500802 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-16.mseed
# 237 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-15T23:29:57.936000Z - 2020-02-16T01:12:25.164000Z | 250.0 Hz, 1536808 samples
# ...
# (235 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-15T23:29:58.164000Z - 2020-02-17T00:30:01.624000Z | 250.0 Hz, 22500866 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-17.mseed
# 249 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-16T23:29:58.032000Z - 2020-02-17T00:04:32.612000Z | 250.0 Hz, 518646 samples
# ...
# (247 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-16T23:29:57.532000Z - 2020-02-18T00:30:02.288000Z | 250.0 Hz, 22501190 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-18.mseed
# 301 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-17T23:29:57.864000Z - 2020-02-18T03:20:59.172000Z | 250.0 Hz, 3465328 samples
# ...
# (299 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-18T16:34:25.924000Z - 2020-02-19T00:30:01.192000Z | 250.0 Hz, 7133818 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-19.mseed
# 477 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-18T23:29:58.024000Z - 2020-02-19T00:51:44.620000Z | 250.0 Hz, 1226650 samples
# ...
# (475 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-19T16:40:54.428000Z - 2020-02-20T00:30:01.808000Z | 250.0 Hz, 7036846 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-20.mseed
# 228 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-19T23:29:58.696000Z - 2020-02-20T00:34:25.284000Z | 250.0 Hz, 966648 samples
# ...
# (226 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-19T23:29:58.268000Z - 2020-02-21T00:30:01.680000Z | 250.0 Hz, 22500854 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-21.mseed
# 250 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-20T23:29:58.584000Z - 2020-02-20T23:33:11.516000Z | 250.0 Hz, 48234 samples
# ...
# (248 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-21T18:01:49.388000Z - 2020-02-22T00:30:01.408000Z | 250.0 Hz, 5823006 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-22.mseed
# 198 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-21T23:29:57.576000Z - 2020-02-21T23:31:25.244000Z | 250.0 Hz, 21918 samples
# ...
# (196 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-22T00:00:01.644000Z - 2020-02-23T00:30:02.472000Z | 250.0 Hz, 22050208 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-23.mseed
# 243 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-22T23:29:58.912000Z - 2020-02-22T23:46:25.060000Z | 250.0 Hz, 246538 samples
# ...
# (241 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-23T00:00:01.188000Z - 2020-02-24T00:30:02.472000Z | 250.0 Hz, 22050322 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-24.mseed
# 8350 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-23T23:29:57.536000Z - 2020-02-25T00:00:01.036000Z | 250.0 Hz, 22050876 samples
# ...
# (8348 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-25T00:00:00.000000Z - 2020-02-25T00:30:01.292000Z | 250.0 Hz, 450324 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-25.mseed
# 5168 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-24T23:29:58.896000Z - 2020-02-25T00:00:01.036000Z | 250.0 Hz, 450536 samples
# ...
# (5166 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-25T00:00:00.000000Z - 2020-02-26T00:30:01.752000Z | 250.0 Hz, 22050439 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-26.mseed
# 341 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-25T23:29:58.564000Z - 2020-02-26T00:03:34.420000Z | 250.0 Hz, 503965 samples
# ...
# (339 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-25T23:29:57.752000Z - 2020-02-27T00:30:02.552000Z | 250.0 Hz, 22501201 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-27.mseed
# 267 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-26T23:29:58.176000Z - 2020-02-27T00:42:55.972000Z | 250.0 Hz, 1094450 samples
# ...
# (265 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-27T14:02:00.220000Z - 2020-02-28T00:30:01.008000Z | 250.0 Hz, 9420198 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-28.mseed
# 246 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-27T23:29:58.384000Z - 2020-02-28T01:13:02.212000Z | 250.0 Hz, 1545958 samples
# ...
# (244 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-27T23:29:58.012000Z - 2020-02-29T00:30:01.368000Z | 250.0 Hz, 22500840 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-02-29.mseed
# 211 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-28T23:29:58.256000Z - 2020-02-28T23:32:34.596000Z | 250.0 Hz, 39086 samples
# ...
# (209 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-28T23:29:57.532000Z - 2020-03-01T00:30:01.492000Z | 250.0 Hz, 22500991 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-03-01.mseed
# 243 Trace(s) in Stream:
#
# CH.SLOP..HGE | 2020-02-29T23:29:58.760000Z - 2020-03-01T01:53:33.492000Z | 250.0 Hz, 2153684 samples
# ...
# (241 other traces)
# ...
# CH.SEPFL..HGZ | 2020-02-29T23:29:57.432000Z - 2020-03-02T00:30:01.708000Z | 250.0 Hz, 22501070 samples
#
# [Use "print(Stream.__str__(extended=True))" to print all Traces]
# 2020-03-02.mseed

# %% [markdown]
# ## Step 4: Compute PPSDs using custom paramters
#
# These parameters are set to allow the PSDs to be "nervous", not as smooth as the default PQLX ones.

# %%
for day in datelist:
    fn_in = day.strftime("%Y-%m-%d.mseed")
    if day == datelist[-1] :
        continue
    stall = read(fn_in)
    for mseedid in list(set([tr.id for tr in stall])):
        fn_out = day.strftime("%Y-%m-%d-"+mseedid+".npz")
        if os.path.isfile(fn_out):
            print("%s done already."%fn_out)
            continue
        st = stall.select(id=mseedid)
        st.attach_response(resp)
        ppsd = PPSD(st[0].stats, metadata=resp,
                    ppsd_length=1800, overlap=0.5,
                    period_smoothing_width_octaves=0.025,
                    period_step_octaves=0.0125,
                    period_limits=(0.008, 50),
                    db_bins=(-200, 20, 0.25))
        ppsd.add(st)
        ppsd.save_npz(fn_out[:-4])
        print(st)
        del st, ppsd
    del stall

# %% [markdown]
# ## Step 5: Reload daily PSDs from the disk and create a single PPSD object:

# %%
ppsds={}
for day in datelist:
    for fn in glob.glob(day.strftime("%Y-%m-%d-*.npz")):
        mseedid = fn.split("-")[3][:-4]
        if mseedid not in ppsds:
            ppsds[mseedid] = PPSD.load_npz(fn,True)
        else:
            ppsds[mseedid].add_npz(fn)
# Out:
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-14-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-14-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-14-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-14-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-14-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-14-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-14-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-14-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-14-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-15-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-15-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-15-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-15-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-15-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-15-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-15-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-15-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-15-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-16-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-16-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-16-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-16-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-17-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-17-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-17-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-17-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-17-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-17-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-17-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-17-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-17-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-18-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-18-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-18-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-18-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-19-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-19-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-19-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-19-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-19-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-19-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-19-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-19-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-19-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-20-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-20-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-20-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-20-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-21-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-21-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-21-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-21-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-21-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-21-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-21-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-21-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-21-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-22-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-22-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-22-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-22-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-23-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-23-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-23-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-23-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-24-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-25-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-25-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-25-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-26-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-26-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-26-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-26-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-27-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-27-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-27-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-27-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-27-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-27-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-27-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-27-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-27-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-28-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-28-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-28-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-28-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-28-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-28-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-28-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-28-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-28-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-29-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-29-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-02-29-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-02-29-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-01-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-01-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-01-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-01-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-02-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-02-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-02-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-02-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-02-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-02-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-02-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-02-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-02-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-03-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 35/130 segments omitted in file '2020-03-03-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-03-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 35/130 segments omitted in file '2020-03-03-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-03-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-03-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 35/130 segments omitted in file '2020-03-03-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-03-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-03-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-04-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-04-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-05-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-05-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-05-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-05-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-05-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-05-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-05-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-05-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-05-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-06-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-06-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-06-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-06-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-06-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-06-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-06-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-06-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-06-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-07-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-07-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-07-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-07-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-07-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-07-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-07-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-07-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-07-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-08-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-08-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-08-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-08-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-08-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-08-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-08-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-08-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-08-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-09-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# ...
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-29-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-29-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-29-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-29-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-29-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-29-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-29-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-29-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-29-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-30-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-30-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-31-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-31-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-31-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-31-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-31-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-03-31-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-31-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-31-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-03-31-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-01-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-01-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-01-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-01-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-02-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-02-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-02-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-02-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-02-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-02-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-02-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-02-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-02-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-03-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-03-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-03-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-03-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-04-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/99 segments omitted in file '2020-04-04-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/99 segments omitted in file '2020-04-04-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SZUZ..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/57 segments omitted in file '2020-04-05-CH.SZUZ..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SGEV..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SGEV..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SBERN..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/57 segments omitted in file '2020-04-05-CH.SGEV..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 4/57 segments omitted in file '2020-04-05-CH.SBERN..HGZ.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SBERN..HGN.npz' (time ranges already covered).
#   warnings.warn(msg)
# /Users/fmassin/anaconda3/lib/python3.5/site-packages/obspy/signal/spectral_estimation.py:1516: UserWarning: 3/57 segments omitted in file '2020-04-05-CH.SZUZ..HGE.npz' (time ranges already covered).
#   warnings.warn(msg)

# %% [markdown]
# ## Step 6: Standard plots:

# %%
[ppsd.plot(max_percentage=10) and break for mseedid, ppsd in ppsds.items()]
[ppsd.plot_temporal(0.10) and break for mseedid, ppsd in ppsds.items()]
[ppsd.plot_spectrogram(clim=(-160,-100))and break for mseedid, ppsd in ppsds.items()]
# Out:
#   File "<ipython-input-9-5450305fc2e3>", line 1
#     [ppsd.plot(max_percentage=10) and break for mseedid, ppsd in ppsds.items()]
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Step 7: Process PSDs to extract the RMS(displacement)
#
# This can be done for multiple filters at once (``freqs`` below):

# %%
# Define frequency bands of interest:
freqs = [(0.1,1.0),(1.0,20.0),(4.0,14.0),(4.0,20.0)]


def rms(s, f):
    # Parseval: the RMS in time domain is the sqrt of the integral of the power spectrum
    return np.sqrt(np.trapz(s, f))

displacement_RMS = {}
for mseedid, ppsd in ppsds.items():
    per = ppsd.period_bin_centers
    displacement_RMS[mseedid] = []
    for psd in ppsd.psd_values:
        RMS = {}
        for fmin, fmax in freqs:
            ix = np.where((per>=1.0/fmax) & (per<=1.0/fmin))

            # acceleration power spectrum in Hz
            spec = psd.copy()[ix][::-1]
            f = 1.0/per.copy()[ix][::-1]

            # remove NaNs from the list
            valid = np.where(np.isfinite(spec))[0]
            spec = spec[valid]
            f = f[valid]

            w2f = (2.0 * np.pi * f)

            # The acceleration amplitude spectrum (dB to Power! = divide by 10 and not 20!)
            amp = 10.0**(spec/10.) 

            # velocity spectrum (divide by omega**2)
            vamp = amp / w2f**2

            # displacement spectrum (divide by omega**2)
            damp =  vamp / w2f**2

            RMS["%.1f-%.1f"%(fmin, fmax)] = rms(damp, f)

        displacement_RMS[mseedid].append(RMS)
        index = pd.DatetimeIndex([d.datetime for d in ppsd.times_processed])
    displacement_RMS[mseedid] = pd.DataFrame(displacement_RMS[mseedid], index=index)
    print(mseedid," rms done.")
# Out:
# CH.SZUZ..HGN  rms done.
# CH.SBERN..HGN  rms done.
# CH.SGEV..HGE  rms done.
# CH.SGEV..HGZ  rms done.
# CH.SZUZ..HGE  rms done.
# CH.SGEV..HGN  rms done.
# CH.SBERN..HGE  rms done.
# CH.SBERN..HGZ  rms done.
# CH.SZUZ..HGZ  rms done.

# %% [markdown]
# ## Step 8: Custom plot for a single frequency band:

# %%
band = "4.0-14.0"
import matplotlib.patheffects as pe

for channelcode in list(set([k[:-1] for k in displacement_RMS])):
    fig = plt.figure(figsize=(12,6))
    try:
        fig.figimage(logo, 40, 40, alpha=.4, zorder=1)
    except:
        pass
    
    Z = displacement_RMS[channelcode+'Z'][band]
    E = displacement_RMS[channelcode+'E'][band]
    N = displacement_RMS[channelcode+'N'][band]
    codes = channelcode[-2:]
    codes = [codes+'*',codes+'Z',codes+'E',codes+'N']
    
    d = Z.copy()
    for i,t in enumerate(d.index):        
        d[i] = 0
        if len(E.index)-1<i or len(N.index)-1<i:
            break
        if (abs(E.index[0].timestamp()-N.index[0].timestamp())<60 and
            abs(Z.index[0].timestamp()-N.index[0].timestamp())<60):
            d[i] = (E[i]**2+N[i]**2+Z[i]**2)**.5
    
    plt.plot(d.index, d, label = codes[0])
    
    for i,data in enumerate([d, Z, E, N]):
        rs = data.copy().between_time("6:00", "16:00")
        rs = rs.resample("1D" ).median().tshift(12, "H")
        plt.plot(rs.index, rs, 
                 label="$\overline{%s}$ (6h-16h)"%codes[i])#, c='purple')

    

    # Get normal business days and set their background color to green
    db = pd.bdate_range(start.datetime, end.datetime)
    for dbi in db:
        plt.axvspan(dbi, dbi+datetime.timedelta(days=1),
                    facecolor='lightgreen', edgecolor="none",
                    alpha=0.2, zorder=-10)

    scale = 1e9
    plt.ylim(0,np.percentile(d,95)*1.1)
    ticks = ticker.FuncFormatter(lambda x, pos: "{0:g}".format(x*scale))
    plt.gca().yaxis.set_major_formatter(ticks)
    plt.ylabel("Displacement (nm)")

    plt.title('Seismic Noise for %s - Filter: [%s] Hz' % (channelcode+'*',
                                                          band))
    plt.xlim(d.index.min(), d.index.max())
    fig.autofmt_xdate()
    plt.grid(True, zorder=-1)
    plt.gca().set_axisbelow(True)    
    for iban,ban in enumerate(bans.keys()):
        plt.axvline(UTCDateTime(ban).datetime,
                    color='r', 
                    linewidth=2,
                    linestyle=['-', '--', '-.', ':'][iban],
                    path_effects=[pe.withStroke(linewidth=4, foreground="k")],
                    zorder=-9,
                    label=bans[b])
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    fig.savefig(channelcode+".pdf",bbox_inches='tight')
    fig.savefig(channelcode+".png",bbox_inches='tight')
