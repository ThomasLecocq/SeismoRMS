# %% [markdown]
# # Ground Motion Displacement RMS vs Time
#
# *an example simple tutorial for getting seismic data, computing the power spectral densities, extracting the RMS and plotting*
#
# Required:
#
# - python
# - obspy (and its dependencies)
# - pandas
# - jupyter
# - notebook
#
# this should be easy to set up in a conda env: ``conda create -n covid python=3.7 obspy pandas jupyter notebook``
#
# Author: Thomas Lecocq @seismotom
# Modified by: @mvanstone

# %% [markdown]
# ## Step 1: imports

# %%
import datetime
import os
import glob

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np


from obspy import UTCDateTime, read
from obspy.clients.fdsn import Client
from obspy.signal import PPSD
import pandas as pd

# %% [markdown]
# ## Step 2: Define Start/End dates and Seismic Channel
#
# You'll have to make sure the seed_id you request is indeed available from the ``data_provider``

# %%
start = UTCDateTime("2019-12-15")  
end = UTCDateTime() # means "now"

network = "AM"
station = "R7FA5"
location = "00"
channel = "EHZ"

data_provider = "RASPISHAKE"

# %% [markdown]
# ## Step 3: Download the seismic waveform data
#
# This step is coded so that only the last day is redownloaded iif the daily files are present on the disk.
#
# The request gets the target day +- 30 minutes to avoid having gaps at the end of each day (need 1 window covering midnight).

# %%
datelist = pd.date_range(start.datetime, end.datetime, freq="D")
c = Client(data_provider)

for day in datelist:
    fn = day.strftime(station + "-%Y-%m-%d.mseed")
    print(fn)
    if day != datelist[-1] and os.path.isfile(fn):
        continue
    else:
        st = c.get_waveforms(network, station, location, channel,
                             UTCDateTime(day)-1801, UTCDateTime(day)+86400+1801, attach_response=True)
        st.merge(method=0, fill_value='latest')
        print(st)
        st.write(fn)
resp = c.get_stations(UTCDateTime(day), network=network, station=station, location=location,
                      channel=channel, level="response")
print(resp)
# Out:
# R7FA5-2019-12-15.mseed
# R7FA5-2019-12-16.mseed
# R7FA5-2019-12-17.mseed
# R7FA5-2019-12-18.mseed
# R7FA5-2019-12-19.mseed
# R7FA5-2019-12-20.mseed
# R7FA5-2019-12-21.mseed
# R7FA5-2019-12-22.mseed
# R7FA5-2019-12-23.mseed
# R7FA5-2019-12-24.mseed
# R7FA5-2019-12-25.mseed
# R7FA5-2019-12-26.mseed
# R7FA5-2019-12-27.mseed
# R7FA5-2019-12-28.mseed
# R7FA5-2019-12-29.mseed
# R7FA5-2019-12-30.mseed
# R7FA5-2019-12-31.mseed
# R7FA5-2020-01-01.mseed
# R7FA5-2020-01-02.mseed
# R7FA5-2020-01-03.mseed
# R7FA5-2020-01-04.mseed
# R7FA5-2020-01-05.mseed
# R7FA5-2020-01-06.mseed
# R7FA5-2020-01-07.mseed
# R7FA5-2020-01-08.mseed
# R7FA5-2020-01-09.mseed
# R7FA5-2020-01-10.mseed
# R7FA5-2020-01-11.mseed
# R7FA5-2020-01-12.mseed
# R7FA5-2020-01-13.mseed
# R7FA5-2020-01-14.mseed
# R7FA5-2020-01-15.mseed
# R7FA5-2020-01-16.mseed
# R7FA5-2020-01-17.mseed
# R7FA5-2020-01-18.mseed
# R7FA5-2020-01-19.mseed
# R7FA5-2020-01-20.mseed
# R7FA5-2020-01-21.mseed
# R7FA5-2020-01-22.mseed
# R7FA5-2020-01-23.mseed
# R7FA5-2020-01-24.mseed
# R7FA5-2020-01-25.mseed
# R7FA5-2020-01-26.mseed
# R7FA5-2020-01-27.mseed
# R7FA5-2020-01-28.mseed
# R7FA5-2020-01-29.mseed
# R7FA5-2020-01-30.mseed
# R7FA5-2020-01-31.mseed
# R7FA5-2020-02-01.mseed
# R7FA5-2020-02-02.mseed
# R7FA5-2020-02-03.mseed
# R7FA5-2020-02-04.mseed
# R7FA5-2020-02-05.mseed
# R7FA5-2020-02-06.mseed
# R7FA5-2020-02-07.mseed
# R7FA5-2020-02-08.mseed
# R7FA5-2020-02-09.mseed
# R7FA5-2020-02-10.mseed
# R7FA5-2020-02-11.mseed
# R7FA5-2020-02-12.mseed
# R7FA5-2020-02-13.mseed
# R7FA5-2020-02-14.mseed
# R7FA5-2020-02-15.mseed
# R7FA5-2020-02-16.mseed
# R7FA5-2020-02-17.mseed
# R7FA5-2020-02-18.mseed
# R7FA5-2020-02-19.mseed
# R7FA5-2020-02-20.mseed
# R7FA5-2020-02-21.mseed
# R7FA5-2020-02-22.mseed
# R7FA5-2020-02-23.mseed
# R7FA5-2020-02-24.mseed
# R7FA5-2020-02-25.mseed
# R7FA5-2020-02-26.mseed
# R7FA5-2020-02-27.mseed
# R7FA5-2020-02-28.mseed
# R7FA5-2020-02-29.mseed
# R7FA5-2020-03-01.mseed
# R7FA5-2020-03-02.mseed
# R7FA5-2020-03-03.mseed
# R7FA5-2020-03-04.mseed
# R7FA5-2020-03-05.mseed
# R7FA5-2020-03-06.mseed
# R7FA5-2020-03-07.mseed
# R7FA5-2020-03-08.mseed
# R7FA5-2020-03-09.mseed
# R7FA5-2020-03-10.mseed
# R7FA5-2020-03-11.mseed
# R7FA5-2020-03-12.mseed
# R7FA5-2020-03-13.mseed
# R7FA5-2020-03-14.mseed
# R7FA5-2020-03-15.mseed
# R7FA5-2020-03-16.mseed
# R7FA5-2020-03-17.mseed
# R7FA5-2020-03-18.mseed
# R7FA5-2020-03-19.mseed
# R7FA5-2020-03-20.mseed
# R7FA5-2020-03-21.mseed
# R7FA5-2020-03-22.mseed
# R7FA5-2020-03-23.mseed
# R7FA5-2020-03-24.mseed
# R7FA5-2020-03-25.mseed
# R7FA5-2020-03-26.mseed
# R7FA5-2020-03-27.mseed
# R7FA5-2020-03-28.mseed
# R7FA5-2020-03-29.mseed
# 1 Trace(s) in Stream:
# AM.R7FA5.00.EHZ | 2020-03-28T23:29:59.000000Z - 2020-03-29T09:34:48.560000Z | 100.0 Hz, 3628957 samples
# Inventory created at 2020-03-29T10:04:47.343053Z
# 	Sending institution: SeisComP3 (gempa testbed)
# 	Contains:
# 		Networks (1):
# 			AM
# 		Stations (1):
# 			AM.R7FA5 (Raspberry Shake Citizen Science Station)
# 		Channels (1):
# 			AM.R7FA5.00.EHZ

# %% [markdown]
# ## Step 4: Compute PPSDs using custom paramters
#
# These parameters are set to allow the PSDs to be "nervous", not as smooth as the default PQLX ones.

# %%
for day in datelist:
    fn_in = day.strftime(station + "-%Y-%m-%d.mseed")
    fn_out = day.strftime(station + "-%Y-%m-%d.npz")
    if day != datelist[-1] and os.path.isfile(fn_out):
        continue
    else:    
        st = read(fn_in)
        st.attach_response(resp)
        print(st)
        ppsd = PPSD(st[0].stats, metadata=resp,
                    ppsd_length=1800, overlap=0.5,
                    period_smoothing_width_octaves=0.025,
                    period_step_octaves=0.0125,
                    period_limits=(0.008, 50),
                    db_bins=(-200, 20, 0.25))
        ppsd.add(st)
        ppsd.save_npz(fn_out[:-4])
        del st, ppsd
# Out:
# 1 Trace(s) in Stream:
# AM.R7FA5.00.EHZ | 2020-03-28T23:29:59.000000Z - 2020-03-29T09:34:48.560000Z | 100.0 Hz, 3628957 samples
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:998: RuntimeWarning: Mean of empty slice.
#   smoothed_psd.append(specs.mean())
# C:\Users\Mark\anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Step 5: Reload daily PSDs from the disk and create a single PPSD object:

# %%
for day in datelist:
    fn = day.strftime(station + "-%Y-%m-%d.npz")
    if day == datelist[0]:
        ppsd = PPSD.load_npz(fn)
    else:
        ppsd.add_npz(fn)
# Out:
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2019-12-16.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-17.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-18.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2019-12-19.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-20.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-21.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-22.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2019-12-23.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-24.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-25.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2019-12-26.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-27.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-28.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-29.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2019-12-30.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2019-12-31.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-01.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-02.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-03.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-04.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-05.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-06.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-07.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-08.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-09.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-10.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-11.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-12.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-13.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-14.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-15.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-16.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/92 segments omitted in file 'R7FA5-2020-01-17.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-19.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-20.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-21.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-22.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-23.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-24.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-25.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-26.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-27.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-28.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-29.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-01-30.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-01-31.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-01.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-02.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-03.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-04.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-05.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-06.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-07.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-08.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-09.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-10.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-11.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-12.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-13.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-14.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-15.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-16.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-17.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-18.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-19.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-20.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-21.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-22.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-23.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-24.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-25.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-02-26.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-27.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-28.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-02-29.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-01.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-02.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-03.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-04.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-05.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-06.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-07.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-08.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-09.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-10.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-11.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-12.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-13.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-14.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-15.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-16.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-17.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-18.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-19.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-20.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-21.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-22.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-23.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-24.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/99 segments omitted in file 'R7FA5-2020-03-25.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-26.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 3/99 segments omitted in file 'R7FA5-2020-03-27.npz' (time ranges already covered).
#   warnings.warn(msg)
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:1539: UserWarning: 4/92 segments omitted in file 'R7FA5-2020-03-28.npz' (time ranges already covered).
#   warnings.warn(msg)

# %% [markdown]
# ## Step 6: Standard plots:

# %%
ppsd.plot(max_percentage=10)
ppsd.plot_temporal(0.10)
ppsd.plot_spectrogram(clim=(-160,-100))
# Out:
# C:\Users\Mark\anaconda3\lib\site-packages\obspy\signal\spectral_estimation.py:2096: MatplotlibDeprecationWarning:
# The set_clim function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use ScalarMappable.set_clim instead.
#   cb.set_clim(*fig.ppsd.color_limits)

# %% [markdown]
# ## Step 7: Process PSDs to extract the RMS(displacement)
#
# This can be done for multiple filters at once (``freqs`` below):

# %%
# Define frequency bands of interest:
freqs = [(0.1,1.0),(1.0,20.0),(4.0,14.0),(4.0,20.0)]


def rms(s, f):
    # Parseval: the RMS in time domain is the sqrt of the integral of the power spectrum
    return np.sqrt(np.trapz(s, f))

per = ppsd.period_bin_centers
displacement_RMS = []
for psd in ppsd.psd_values:
    RMS = {}
    for fmin, fmax in freqs:
        ix = np.where((per>=1.0/fmax) & (per<=1.0/fmin))

        # acceleration power spectrum in Hz
        spec = psd.copy()[ix][::-1]
        f = 1.0/per.copy()[ix][::-1]

        # remove NaNs from the list
        valid = np.where(np.isfinite(spec))[0]
        spec = spec[valid]
        f = f[valid]

        w2f = (2.0 * np.pi * f)
        
        # The acceleration amplitude spectrum (dB to Power! = divide by 10 and not 20!)
        amp = 10.0**(spec/10.) 
        
        # velocity spectrum (divide by omega**2)
        vamp = amp / w2f**2
         
        # displacement spectrum (divide by omega**2)
        damp =  vamp / w2f**2

        RMS["%.1f-%.1f"%(fmin, fmax)] = rms(damp, f)

    displacement_RMS.append(RMS)
index = pd.DatetimeIndex([d.datetime for d in ppsd.times_processed])
displacement_RMS = pd.DataFrame(displacement_RMS, index=index)

# %% [markdown]
# ## Step 8: Custom plot for a single frequency band:

# %%
band = "4.0-14.0"

fig = plt.figure(figsize=(12,6))
d = displacement_RMS[band]
plt.plot(d.index, d)


# Get normal business days and set their background color to green
db = pd.bdate_range(start.datetime, end.datetime)
for dbi in db:
    plt.axvspan(dbi, dbi+datetime.timedelta(days=1),
                facecolor='lightgreen', edgecolor="none",
                alpha=0.2, zorder=-10)


rs = d.copy().between_time("6:00", "16:00")
rs = rs.resample("1D" ).mean().tshift(12, "H")
plt.plot(rs.index, rs, label="$\overline{x}$ (6h-16h)", c='purple')
    


scale = 1e9
ticks = ticker.FuncFormatter(lambda x, pos: "{0:g}".format(x*scale))
plt.gca().yaxis.set_major_formatter(ticks)
plt.ylabel("Displacement (nm)")

plt.ylim(0,0.3e-9)
plt.title('Seismic Noise for %s - Filter: [%s] Hz' % ("%s.%s.%s.%s" % (network, station, location, channel),
                                                      band))
plt.xlim(d.index.min(), d.index.max())
fig.autofmt_xdate()
plt.grid(True, zorder=-1)
plt.gca().set_axisbelow(True)
plt.show()
